# %% [markdown]
# # Notebook TUI Rich Demo
#
# This notebook tests markdown blocks, tables, inline code, and code execution.
#
# - Bullet list item A
# - Bullet list item B
#
# Inline code: `sum(range(10))`

# %% [markdown]
# ![](./rnb.png)

# %% [markdown]
# ## Table + HTML snippet
#
# > test
#
# | Name | Value |
# | --- | ---: |
# | Alpha | 123 |
# | Beta | 456 |
#
# <b>HTML Bold</b> and <i>HTML Italic</i> should still be readable as text.
#
# > Quote block to test markdown formatting text.

# %%
import math
numbers = [1, 2, 3, 4, 5]
print('sum =', sum(numbers))
print('sqrt(2) =', round(math.sqrt(2), 6))
# Out:
# sum = 15
# sqrt(2) = 1.414214

# %%
# Variable reuse test
x = 10
y = 32
print('x + y =', x + y)
for i in range(3):
    print('loop', i)
# Out:
# x + y = 42
# loop 0
# loop 1
# loop 2

# %%
# Error rendering test
def divide(a, b):
    return a / b

print('safe divide:', divide(8, 2))
print('error divide:', divide(8, 0))
# Out:
# Traceback (most recent call last):
#   File "<string>", line 69, in _execute_fallback
#   File "<string>", line 6, in <module>
#   File "<string>", line 3, in divide
# ZeroDivisionError: division by zero
